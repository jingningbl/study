# %% [markdown]
# ##### 区域地图

# %%
from pyecharts.charts import *
from pyecharts import options as opts

# %%
# 虚假示例数据
data = [('广东', 61), ('湖北', 85), ('湖南', 115), ('四川', 137), ('重庆', 119), ('黑龙江', 66), ('浙江', 117),
        ('山西', 52), ('河北', 80), ('安徽', 99), ('河南', 101), ('山东', 75), ('西藏', 53)]

chart = Map()
chart.add(
    "", 
    data, 
    # 必须的参数，指定地图类型
    maptype='china'
    )

chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="06a3c31fff584c8f977e843af9ebc19d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_06a3c31fff584c8f977e843af9ebc19d = echarts.init(
#                     document.getElementById('06a3c31fff584c8f977e843af9ebc19d'), 'white', {renderer: 'canvas'});
#                 var option_06a3c31fff584c8f977e843af9ebc19d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
# 虚假示例数据
data = [('广东', 61), ('湖北', 85), ('湖南', 115), ('四川', 137), ('重庆', 119), ('黑龙江', 66), ('浙江', 117),
        ('山西', 52), ('河北', 80), ('安徽', 99), ('河南', 101), ('山东', 75), ('西藏', 53)]

chart = Geo()
chart.add_schema(
    maptype='china'
)
chart.add(
    "", 
    data
    )

chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="5f0174a6bce749e09675496a073bac83" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_5f0174a6bce749e09675496a073bac83 = echarts.init(
#                     document.getElementById('5f0174a6bce749e09675496a073bac83'), 'white', {renderer: 'canvas'});
#                 var option_5f0174a6bce749e09675496a073bac83 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
# 虚假数据
data_pair = [['Apple', 123], ['Huawei', 153], ['Xiaomi', 89], ['Oppo', 107], ['Vivo', 98], ['Meizu', 23]]

chart = Pie()
chart.add(
       '', 
       data_pair
       )
       
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d518a23ab7cf4c42abe38e75529a4abc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d518a23ab7cf4c42abe38e75529a4abc = echarts.init(
#                     document.getElementById('d518a23ab7cf4c42abe38e75529a4abc'), 'white', {renderer: 'canvas'});
#                 var option_d518a23ab7cf4c42abe38e75529a4abc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
# 虚假数据
data_pair = [['访问', 30398], ['注册', 15230], ['加入购物车', 10045], ['提交订单', 3109], ['付款成功', 1698]]

chart = Funnel()
chart.add(
    "", 
    data_pair
    )

chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2ee8dffce34d4dd1b71daadc167b7853" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2ee8dffce34d4dd1b71daadc167b7853 = echarts.init(
#                     document.getElementById('2ee8dffce34d4dd1b71daadc167b7853'), 'white', {renderer: 'canvas'});
#                 var option_2ee8dffce34d4dd1b71daadc167b7853 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
data = [['2021-08-01', 100], ['2021-08-02', 54], ['2021-08-03', 41], ['2021-08-04', 98], ['2021-08-05', 65], ['2021-08-06', 28], 
        ['2021-08-07', 96], ['2021-08-08', 75], ['2021-08-09', 14], ['2021-08-10', 91], ['2021-08-11', 83], ['2021-08-12', 0], 
        ['2021-08-13', 84], ['2021-08-14', 90], ['2021-08-15', 13], ['2021-08-16', 75], ['2021-08-17', 95], ['2021-08-18', 27], 
        ['2021-08-19', 66], ['2021-08-20', 98], ['2021-08-21', 40], ['2021-08-22', 54], ['2021-08-23', 99], ['2021-08-24', 53], 
        ['2021-08-25', 42], ['2021-08-26', 99], ['2021-08-27', 64], ['2021-08-28', 29], ['2021-08-29', 96], ['2021-08-30', 74], 
        ['2021-08-31', 15]]

chart = Calendar()
chart.add(
        "", 
        data, 
        calendar_opts=opts.CalendarOpts(
                # 设置日期起止范围
                range_=['2021-08-01', '2021-08-31']
                )
        )

# 全局配置项, HeatMap需要配合视觉组件
chart.set_global_opts(
    visualmap_opts=opts.VisualMapOpts(
        type_='color'
    ),
)

chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="736ccaaf7b364aa9acca1260b5a347e8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_736ccaaf7b364aa9acca1260b5a347e8 = echarts.init(
#                     document.getElementById('736ccaaf7b364aa9acca1260b5a347e8'), 'white', {renderer: 'canvas'});
#                 var option_736ccaaf7b364aa9acca1260b5a347e8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
words = [
    ("Sam S Club", 10000),
    ("Macys", 6181),
    ("Amy Schumer", 4386),
    ("Jurassic World", 4055),
    ("Charter Communications", 2467),
    ("Chick Fil A", 2244),
    ("Planet Fitness", 1868),
    ("Pitch Perfect", 1484),
    ("Express", 1112),
    ("Home", 865),
    ("Johnny Depp", 847),
    ("Lena Dunham", 582),
    ("Lewis Hamilton", 555),
    ("KXAN", 550),
    ("Mary Ellen Mark", 462),
    ("Farrah Abraham", 366),
    ("Rita Ora", 360),
    ("Serena Williams", 282),
    ("NCAA baseball tournament", 273),
    ("Point Break", 265),
]

chart = WordCloud()
chart.add(
    "", 
    words
    )

chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="b7e283774bad4aacb3f31886aa5bf13d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_b7e283774bad4aacb3f31886aa5bf13d = echarts.init(
#                     document.getElementById('b7e283774bad4aacb3f31886aa5bf13d'), 'white', {renderer: 'canvas'});
#                 var option_b7e283774bad4aacb3f31886aa5bf13d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
# ...
